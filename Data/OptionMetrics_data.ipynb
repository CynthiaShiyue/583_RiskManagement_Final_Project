# %%
import wrds
db = wrds.Connection()

db.list_tables(library='optionm_all')
# Out:
# Loading library list...
# Done
# ['borrate1996',
#  'borrate1997',
#  'borrate1998',
#  'borrate1999',
#  'borrate2000',
#  'borrate2001',
#  'borrate2002',
#  'borrate2003',
#  'borrate2004',
#  'borrate2005',
#  'borrate2006',
#  'borrate2007',
#  'borrate2008',
#  'borrate2009',
#  'borrate2010',
#  'borrate2011',
#  'borrate2012',
#  'borrate2013',
#  'borrate2014',
#  'borrate2015',
#  'borrate2016',
#  'borrate2017',
#  'borrate2018',
#  'borrate2019',
#  'borrate2020',
#  'borrate2021',
#  'borrate2022',
#  'borrate2023',
#  'distrd',
#  'distrprojd1996',
#  'distrprojd1997',
#  'distrprojd1998',
#  'distrprojd1999',
#  'distrprojd2000',
#  'distrprojd2001',
#  'distrprojd2002',
#  'distrprojd2003',
#  'distrprojd2004',
#  'distrprojd2005',
#  'distrprojd2006',
#  'distrprojd2007',
#  'distrprojd2008',
#  'distrprojd2009',
#  'distrprojd2010',
#  'distrprojd2011',
#  'distrprojd2012',
#  'distrprojd2013',
#  'distrprojd2014',
#  'distrprojd2015',
#  'distrprojd2016',
#  'distrprojd2017',
#  'distrprojd2018',
#  'distrprojd2019',
#  'distrprojd2020',
#  'distrprojd2021',
#  'distrprojd2022',
#  'distrprojd2023',
#  'exchgd',
#  'fwdprd1996',
#  'fwdprd1997',
#  'fwdprd1998',
#  'fwdprd1999',
#  'fwdprd2000',
#  'fwdprd2001',
#  'fwdprd2002',
#  'fwdprd2003',
#  'fwdprd2004',
#  'fwdprd2005',
#  'fwdprd2006',
#  'fwdprd2007',
#  'fwdprd2008',
#  'fwdprd2009',
#  'fwdprd2010',
#  'fwdprd2011',
#  'fwdprd2012',
#  'fwdprd2013',
#  'fwdprd2014',
#  'fwdprd2015',
#  'fwdprd2016',
#  'fwdprd2017',
#  'fwdprd2018',
#  'fwdprd2019',
#  'fwdprd2020',
#  'fwdprd2021',
#  'fwdprd2022',
#  'fwdprd2023',
#  'hvold1996',
#  'hvold1997',
#  'hvold1998',
#  'hvold1999',
#  'hvold2000',
#  'hvold2001',
#  'hvold2002',
#  'hvold2003',
#  'hvold2004',
#  'hvold2005',
#  'hvold2006',
#  'hvold2007',
#  'hvold2008',
#  'hvold2009',
#  'hvold2010',
#  'hvold2011',
#  'hvold2012',
#  'hvold2013',
#  'hvold2014',
#  'hvold2015',
#  'hvold2016',
#  'hvold2017',
#  'hvold2018',
#  'hvold2019',
#  'hvold2020',
#  'hvold2021',
#  'hvold2022',
#  'hvold2023',
#  'idxdvd',
#  'indexd',
#  'opinfd',
#  'opprcd1996',
#  'opprcd1997',
#  'opprcd1998',
#  'opprcd1999',
#  'opprcd2000',
#  'opprcd2001',
#  'opprcd2002',
#  'opprcd2003',
#  'opprcd2004',
#  'opprcd2005',
#  'opprcd2006',
#  'opprcd2007',
#  'opprcd2008',
#  'opprcd2009',
#  'opprcd2010',
#  'opprcd2011',
#  'opprcd2012',
#  'opprcd2013',
#  'opprcd2014',
#  'opprcd2015',
#  'opprcd2016',
#  'opprcd2017',
#  'opprcd2018',
#  'opprcd2019',
#  'opprcd2020',
#  'opprcd2021',
#  'opprcd2022',
#  'opprcd2023',
#  'optionmnames',
#  'opvold',
#  'secnmd',
#  'secprd',
#  'secprd1996',
#  'secprd1997',
#  'secprd1998',
#  'secprd1999',
#  'secprd2000',
#  'secprd2001',
#  'secprd2002',
#  'secprd2003',
#  'secprd2004',
#  'secprd2005',
#  'secprd2006',
#  'secprd2007',
#  'secprd2008',
#  'secprd2009',
#  'secprd2010',
#  'secprd2011',
#  'secprd2012',
#  'secprd2013',
#  'secprd2014',
#  'secprd2015',
#  'secprd2016',
#  'secprd2017',
#  'secprd2018',
#  'secprd2019',
#  'secprd2020',
#  'secprd2021',
#  'secprd2022',
#  'secprd2023',
#  'securd',
#  'securd1',
#  'stdbrte1996',
#  'stdbrte1997',
#  'stdbrte1998',
#  'stdbrte1999',
#  'stdbrte2000',
#  'stdbrte2001',
#  'stdbrte2002',
#  'stdbrte2003',
#  'stdbrte2004',
#  'stdbrte2005',
#  'stdbrte2006',
#  'stdbrte2007',
#  'stdbrte2008',
#  'stdbrte2009',
#  'stdbrte2010',
#  'stdbrte2011',
#  'stdbrte2012',
#  'stdbrte2013',
#  'stdbrte2014',
#  'stdbrte2015',
#  'stdbrte2016',
#  'stdbrte2017',
#  'stdbrte2018',
#  'stdbrte2019',
#  'stdbrte2020',
#  'stdbrte2021',
#  'stdbrte2022',
#  'stdbrte2023',
#  'stdopd1996',
#  'stdopd1997',
#  'stdopd1998',
#  'stdopd1999',
#  'stdopd2000',
#  'stdopd2001',
#  'stdopd2002',
#  'stdopd2003',
#  'stdopd2004',
#  'stdopd2005',
#  'stdopd2006',
#  'stdopd2007',
#  'stdopd2008',
#  'stdopd2009',
#  'stdopd2010',
#  'stdopd2011',
#  'stdopd2012',
#  'stdopd2013',
#  'stdopd2014',
#  'stdopd2015',
#  'stdopd2016',
#  'stdopd2017',
#  'stdopd2018',
#  'stdopd2019',
#  'stdopd2020',
#  'stdopd2021',
#  'stdopd2022',
#  'stdopd2023',
#  'vsurfd1996',
#  'vsurfd1997',
#  'vsurfd1998',
#  'vsurfd1999',
#  'vsurfd2000',
#  'vsurfd2001',
#  'vsurfd2002',
#  'vsurfd2003',
#  'vsurfd2004',
#  'vsurfd2005',
#  'vsurfd2006',
#  'vsurfd2007',
#  'vsurfd2008',
#  'vsurfd2009',
#  'vsurfd2010',
#  'vsurfd2011',
#  'vsurfd2012',
#  'vsurfd2013',
#  'vsurfd2014',
#  'vsurfd2015',
#  'vsurfd2016',
#  'vsurfd2017',
#  'vsurfd2018',
#  'vsurfd2019',
#  'vsurfd2020',
#  'vsurfd2021',
#  'vsurfd2022',
#  'vsurfd2023',
#  'zerocd']

# %%
db.describe_table(library='optionm_all', table='secnmd')
# Out:
# Approximately 265203 rows in optionm_all.secnmd.
#           name  nullable              type                             comment
# 0        secid      True  DOUBLE PRECISION                         Security ID
# 1  effect_date      True              DATE                      Effective Date
# 2        cusip      True        VARCHAR(8)                        CUSIP Number
# 3       ticker      True        VARCHAR(6)                       Ticker Symbol
# 4        class      True        VARCHAR(1)                    Class Designator
# 5       issuer      True       VARCHAR(28)  Description of the Issuing Company
# 6        issue      True       VARCHAR(20)            Description of the Issue
# 7          sic      True        VARCHAR(4)                            SIC Code

# %%
QQQ_secid = db.raw_sql("""
SELECT DISTINCT secid, ticker, issuer
FROM optionm_all.secnmd
WHERE ticker = 'QQQ'
""")
QQQ_secid
# Out:
#       secid ticker                        issuer
# 0  107899.0    QQQ  INVESCO CAPITAL MANAGEMENT L
# 1  107899.0    QQQ                 NASDAQ 100 TR
# 2  107899.0    QQQ         POWERSHARES QQQ TRUST

# %%
db.describe_table(library='optionm_all', table='opprcd2023')
# Out:
# Approximately 232031728 rows in optionm_all.opprcd2023.
#                 name  nullable              type comment
# 0              secid      True  DOUBLE PRECISION    None
# 1               date      True              DATE    None
# 2             symbol      True       VARCHAR(21)    None
# 3        symbol_flag      True        VARCHAR(1)    None
# 4             exdate      True              DATE    None
# 5          last_date      True              DATE    None
# 6            cp_flag      True        VARCHAR(1)    None
# 7       strike_price      True  DOUBLE PRECISION    None
# 8           best_bid      True  DOUBLE PRECISION    None
# 9         best_offer      True  DOUBLE PRECISION    None
# 10            volume      True  DOUBLE PRECISION    None
# 11     open_interest      True  DOUBLE PRECISION    None
# 12   impl_volatility      True  DOUBLE PRECISION    None
# 13             delta      True  DOUBLE PRECISION    None
# 14             gamma      True  DOUBLE PRECISION    None
# 15              vega      True  DOUBLE PRECISION    None
# 16             theta      True  DOUBLE PRECISION    None
# 17          optionid      True  DOUBLE PRECISION    None
# 18             cfadj      True  DOUBLE PRECISION    None
# 19     am_settlement      True  DOUBLE PRECISION    None
# 20     contract_size      True  DOUBLE PRECISION    None
# 21           ss_flag      True        VARCHAR(1)    None
# 22     forward_price      True  DOUBLE PRECISION    None
# 23  expiry_indicator      True        VARCHAR(1)    None
# 24              root      True        VARCHAR(5)    None
# 25            suffix      True        VARCHAR(2)    None

# %%
df_opt = db.raw_sql("""
SELECT 
  date,
  exdate,
  cp_flag,
  strike_price,
  delta,
  gamma,
  impl_volatility,
  best_bid,
  best_offer,
  volume,
  open_interest,
  optionid,
  secid
FROM optionm_all.opprcd2023
WHERE 
  secid = 107899
  AND date BETWEEN '2023-01-01' AND '2023-12-31'
  AND delta IS NOT NULL
  AND gamma IS NOT NULL
  AND impl_volatility IS NOT NULL
  AND volume > 0
  AND open_interest > 0
  AND (exdate - date) BETWEEN 25 AND 45

""")
df_opt.tail()
# Out:
#              date      exdate cp_flag  strike_price     delta     gamma  \
# 64438  2023-05-01  2023-06-09       P      324000.0 -0.506181  0.022442
# 64439  2023-05-01  2023-06-09       P      325000.0 -0.529266  0.022815
# 64440  2023-05-01  2023-06-09       P      326000.0 -0.552952  0.023129
# 64441  2023-05-01  2023-06-09       P      330000.0 -0.651346  0.023545
# 64442  2023-05-01  2023-06-09       P      333000.0 -0.728984  0.023194
#
#        impl_volatility  best_bid  best_offer  volume  open_interest  \
# 64438         0.176600      7.66        7.69     9.0            4.0
# 64439         0.174236      8.10        8.13    66.0          109.0
# 64440         0.171919      8.56        8.60    34.0            1.0
# 64441         0.164026     10.67       10.82    10.0            9.0
# 64442         0.157359     12.53       12.71     3.0            3.0
#
#           optionid     secid
# 64438  154160475.0  107899.0
# 64439  154160476.0  107899.0
# 64440  154160477.0  107899.0
# 64441  154189167.0  107899.0
# 64442  154189170.0  107899.0

# %%
import pandas as pd

years = range(2018, 2024)  # 2023 included

dfs = []

sql_template = """
SELECT 
  date,
  exdate,
  cp_flag,
  strike_price,
  delta,
  gamma,
  impl_volatility,
  best_bid,
  best_offer,
  volume,
  open_interest,
  optionid,
  secid
FROM optionm_all.opprcd{year}
WHERE 
  secid = 107899
  AND date BETWEEN '{start}' AND '{end}'
  AND delta IS NOT NULL
  AND gamma IS NOT NULL
  AND impl_volatility IS NOT NULL
  AND volume > 0
  AND open_interest > 0
  AND (exdate - date) BETWEEN 25 AND 45
"""

for year in years:
    start = f"{year}-01-01"
    end = f"{year}-12-31"
    query = sql_template.format(year=year, start=start, end=end)
    print(f"Extracting {year}...")
    df_year = db.raw_sql(query)
    dfs.append(df_year)

df_opt_all = pd.concat(dfs, ignore_index=True)

df_opt_all.head()
# Out:
# Extracting 2018...
# Extracting 2019...
# Extracting 2020...
# Extracting 2021...
# Extracting 2022...
# Extracting 2023...
#          date      exdate cp_flag  strike_price     delta     gamma  \
# 0  2018-01-02  2018-02-02       C      148500.0  0.892498  0.021384
# 1  2018-01-02  2018-02-02       C      149500.0  0.875178  0.024551
# 2  2018-01-02  2018-02-02       C      153000.0  0.791621  0.039376
# 3  2018-01-02  2018-02-02       C      153500.0  0.776244  0.042127
# 4  2018-01-02  2018-02-02       C      154000.0  0.758090  0.044900
#
#    impl_volatility  best_bid  best_offer  volume  open_interest     optionid  \
# 0         0.186879     10.49       10.70     4.0           40.0  118524041.0
# 1         0.181047      9.61        9.73     2.0           12.0  118524043.0
# 2         0.157560      6.48        6.56     3.0           42.0  118524049.0
# 3         0.153491      6.05        6.11    11.0           98.0  118524050.0
# 4         0.150400      5.63        5.69    20.0           91.0  118524051.0
#
#       secid
# 0  107899.0
# 1  107899.0
# 2  107899.0
# 3  107899.0
# 4  107899.0

# %%
df_opt_all.to_csv("qqq_option_data_2018_2023.csv", index=False)
